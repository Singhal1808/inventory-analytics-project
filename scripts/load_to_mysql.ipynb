# %%
import pandas as pd
import mysql.connector

# Load data
df = pd.read_csv("../data/kpi_sales_data.csv")

print("Rows to insert:", len(df))

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="18082003",
    database="retail_sales_db"
)

cursor = conn.cursor()

query = """
INSERT INTO sales_data
(date, store_id, item_id,
 sales, price, promo,
 weekday, month,
 Demand_Forecast,
 Inventory_Level,
 Stockout_Risk)
VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
"""

data = df.values.tolist()

cursor.executemany(query, data)

conn.commit()

print("Data inserted successfully")
# Out:
# Rows to insert: 182600
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[7], line 31
#      18 query = """
#      19 INSERT INTO sales_data
#      20 (date, store_id, item_id,
#    (...)     26 VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
#      27 """
#      29 data = df.values.tolist()
# ---> 31 cursor.executemany(query, data)
#      33 conn.commit()
#      35 print("Data inserted successfully")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mysql\connector\cursor.py:519, in MySQLCursor.executemany(self, operation, seq_params)
#     517     self._rowcount = 0
#     518     return None
# --> 519 stmt = self._batch_insert(operation, seq_params)
#     520 if stmt is not None:
#     521     self._executed = stmt
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mysql\connector\cursor.py:465, in MySQLCursor._batch_insert(self, operation, seq_params)
#     463         tmp = RE_PY_PARAM.sub(psub, tmp)
#     464         if psub.remaining != 0:
# --> 465             raise ProgrammingError(
#     466                 "Not all parameters were used in the SQL statement"
#     467             )
#     468     values.append(tmp)
#     469 if fmt in stmt:
#
# ProgrammingError: Not all parameters were used in the SQL statement
